# %%
import pathlib
import json

odds = json.loads(pathlib.Path('pull_odds.json').read_text())

for key,value in odds.items():
    print(key, len(value))
# Out:
# debut 301
# limited_any 301
# limited_specific 301
# limited_both 301

# %%
import pandas as pd

df = pd.read_json('pull_odds.json')
df['pulls'] = range(301)

df
# Out:
#       debut  limited_any  limited_specific  limited_both  pulls
# 0      0.00        0.000             0.000       0.00000      0
# 1      1.00        1.400             0.700       0.00000      1
# 2      1.99        2.780             1.395       0.00980      2
# 3      2.97        4.141             2.085       0.02919      3
# 4      3.94        5.483             2.771       0.05798      4
# ..      ...          ...               ...           ...    ...
# 296  100.00       99.970            96.250      92.53000    296
# 297  100.00       99.970            96.300      92.62000    297
# 298  100.00       99.980            96.340      92.70000    298
# 299  100.00       99.980            96.380      92.79000    299
# 300  100.00       99.980            96.420      92.87000    300
#
# [301 rows x 5 columns]
